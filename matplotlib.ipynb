# %%
# import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 4

import numpy as np
# dates = pd.date_range('20171201', periods=30)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
y1= np.random.rand(1,10)[0] 
y2= np.random.rand(1,10)[0]

# %%
#multiple series
plt.plot(y1,label='y1');
plt.plot(y2,label='y2');
plt.legend(loc='best');

# %%
#small multiples
plt.subplot(121) # subplots will be 1 row by 2 columns
plt.axis([0, 6, 0, 20]) # set axis 0 to 6 and 0 to 20
plt.ylabel('rand #s')
plt.plot(y1,'bo'); #blue dots

plt.subplot(122)
plt.title('title')
plt.plot(y2,color='r');

# %%
from matplotlib import style
style.use('fivethirtyeight')

# define x values from 5 to 15, incrementing by 2
x = np.arange(5,25,2)
noOut = plt.plot(x,y1)

# show values
for i,j in zip(x,y1):  #zip is used to return multiple iterators
    noOut = plt.annotate('{:.2f}'.format(j),xy=(i,j))

# %%
ax = plt.figure().add_subplot(111)
ax.set_ylim(.75,.95)
plt.bar(x,y1,alpha=.5); #could use barh too

# %%
plt.hist(y1);

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

# Generate a large random dataset
rs = np.random.RandomState(33)
d = pd.DataFrame(data=rs.normal(size=(100, 26)),
                 columns=list(ascii_letters[26:]))

# Compute the correlation matrix
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()

# %% [raw]
# import matplotlib.pyplot as plt
# import numpy as np
# import mpld3
#
# fig, ax = plt.subplots(subplot_kw=dict(axisbg='#EEEEEE'))
# N = 100
#
# scatter = ax.scatter(np.random.normal(size=N),
#                      np.random.normal(size=N),
#                      c=np.random.random(size=N),
#                      s=1000 * np.random.random(size=N),
#                      alpha=0.3,
#                      cmap=plt.cm.jet)
# ax.grid(color='white', linestyle='solid')
#
# ax.set_title("Scatter Plot (with tooltips!)", size=20)
#
# labels = ['point {0}'.format(i + 1) for i in range(N)]
# tooltip = mpld3.plugins.PointLabelTooltip(scatter, labels=labels)
# mpld3.plugins.connect(fig, tooltip)
#
# mpld3.show()

# %%
# generate larger table
dates = pd.date_range('20130101', periods=6)
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=['A', 'B', 'C', 'D'])
df
# Out:
#                    A         B         C         D
# 2013-01-01  1.129212 -0.836864  0.887567 -0.290112
# 2013-01-02  0.981340 -0.655333  0.168674 -0.370929
# 2013-01-03 -0.747848  2.871599 -1.084850 -2.490280
# 2013-01-04 -1.598547  0.768672  1.352675  1.313783
# 2013-01-05  0.422161  1.068658  0.290523 -1.243740
# 2013-01-06  0.181038  1.274036  1.552594  0.728215

# %%
plt.plot(df.A)
